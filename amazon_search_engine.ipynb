# %%
import numpy as np
import pandas as pd
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sachk\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
data = pd.read_csv('amazon_product.csv')
data.head()
# Out:
#    id                                              Title  \
# 0   1   Swissmar Capstore Select Storage Rack for 18-...
# 1   2   Gemini200 Delta CV-880 Gold Crown Livery Airc...
# 2   5   Superior Threads 10501-2172 Magnifico Cream P...
# 3   6            Fashion Angels Color Rox Hair Chox Kit
# 4   8   Union Creative Giant Killing Figure 05: Daisu...
#
#                                          Description  \
# 0  Swissmar's capstore select 18 storage unit kee...
# 1  Welcome to the exciting world of GeminiJets! O...
# 2  For quilting and embroidery, this product is m...
# 3  Experiment with the haute trend of hair chalki...
# 4  From Union Creative. Turn your display shelf i...
#
#                                             Category
# 0   Home & Kitchen Kitchen & Dining Kitchen Utens...
# 1   Toys & Games Hobbies Models & Model Kits Pre-...
# 2   Arts, Crafts & Sewing Sewing Thread & Floss S...
# 3   Beauty & Personal Care Hair Care Hair Colorin...
# 4   Toys & Games › Action Figures & Statues › Sta...

# %%
data = data.drop('id', axis=1)
data.head()
# Out:
#                                                Title  \
# 0   Swissmar Capstore Select Storage Rack for 18-...
# 1   Gemini200 Delta CV-880 Gold Crown Livery Airc...
# 2   Superior Threads 10501-2172 Magnifico Cream P...
# 3            Fashion Angels Color Rox Hair Chox Kit
# 4   Union Creative Giant Killing Figure 05: Daisu...
#
#                                          Description  \
# 0  Swissmar's capstore select 18 storage unit kee...
# 1  Welcome to the exciting world of GeminiJets! O...
# 2  For quilting and embroidery, this product is m...
# 3  Experiment with the haute trend of hair chalki...
# 4  From Union Creative. Turn your display shelf i...
#
#                                             Category
# 0   Home & Kitchen Kitchen & Dining Kitchen Utens...
# 1   Toys & Games Hobbies Models & Model Kits Pre-...
# 2   Arts, Crafts & Sewing Sewing Thread & Floss S...
# 3   Beauty & Personal Care Hair Care Hair Colorin...
# 4   Toys & Games › Action Figures & Statues › Sta...

# %%
data.isnull().sum()
# Out:
# Title          0
# Description    0
# Category       0
# dtype: int64

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer('english')
def tokenize_and_stem(text):
    tokens = nltk.word_tokenize(text.lower())
    stems = [stemmer.stem(t) for t in tokens]
    return stems

# %%
data['stemmed_tokens'] = data.apply(lambda row: tokenize_and_stem(row['Title'] + ' ' + row['Description']), axis=1)

# %%
data.head()
# Out:
#                                                Title  \
# 0   Swissmar Capstore Select Storage Rack for 18-...
# 1   Gemini200 Delta CV-880 Gold Crown Livery Airc...
# 2   Superior Threads 10501-2172 Magnifico Cream P...
# 3            Fashion Angels Color Rox Hair Chox Kit
# 4   Union Creative Giant Killing Figure 05: Daisu...
#
#                                          Description  \
# 0  Swissmar's capstore select 18 storage unit kee...
# 1  Welcome to the exciting world of GeminiJets! O...
# 2  For quilting and embroidery, this product is m...
# 3  Experiment with the haute trend of hair chalki...
# 4  From Union Creative. Turn your display shelf i...
#
#                                             Category  \
# 0   Home & Kitchen Kitchen & Dining Kitchen Utens...
# 1   Toys & Games Hobbies Models & Model Kits Pre-...
# 2   Arts, Crafts & Sewing Sewing Thread & Floss S...
# 3   Beauty & Personal Care Hair Care Hair Colorin...
# 4   Toys & Games › Action Figures & Statues › Sta...
#
#                                       stemmed_tokens
# 0  [swissmar, capstor, select, storag, rack, for,...
# 1  [gemini200, delta, cv-880, gold, crown, liveri...
# 2  [superior, thread, 10501-2172, magnifico, crea...
# 3  [fashion, angel, color, rox, hair, chox, kit, ...
# 4  [union, creativ, giant, kill, figur, 05, :, da...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
tfidf_vectorizer = TfidfVectorizer(tokenizer=tokenize_and_stem)
def cosine_sim(text1, text2):
    text1_concatenated = ' '.join(text1)
    text2_concatenated = ' '.join(text2)
    tfidf_matrix = tfidf_vectorizer.fit_transform([text1_concatenated, text2_concatenated])
    return cosine_similarity(tfidf_matrix)[0][1]

# %%
def search_products(query):
    query_stemmed = tokenize_and_stem(query)
    data['similarity'] = data['stemmed_tokens'].apply(lambda x: cosine_sim(query_stemmed, x))
    results = data.sort_values(by=['similarity'], ascending=False).head(10)[['Title', 'Description', 'Category']]
    return results

# %%
res = search_products(data['Title'][0])
res
# Out:
#                                                  Title  \
# 0     Swissmar Capstore Select Storage Rack for 18-...
# 541         Remington SP290 for F4790 Shaver (2-Pack)
# 34           Gear Aid Replacement Triglide Buckle Kit
# 551   C2G 03836 2-Port Cat5e Surface Mount Box, Ivory
# 285             SleepRight Ultra-Comfort Dental Guard
# 240   C-Line Poly 3-Compartment Storage Box with Sn...
# 381       Zoom 6" Lizard Plastic Fishing Baits 9-Pack
# 349   Fixodent Free Denture Adhesive Cream 2.40 Oun...
# 463   Versio Mobile 3-Pack Screen Protector for LG ...
# 40      Rivacase Ladies 15.6 Inch Laptop Shoulder Bag
#
#                                            Description  \
# 0    Swissmar's capstore select 18 storage unit kee...
# 541  Technical Features for Remington SP290-2 The R...
# 34   When you need to lengthen or shorten straps an...
# 551  Ideal for surface mount applications, especial...
# 285  For the most up to date information, we recomm...
# 240  C-Line's durable storage box features three co...
# 381  The Zoom Lizard gives anglers a wide color sel...
# 349  For the most up to date information, we recomm...
# 463           Clear 3 Pack Screen Protector For LG G2
# 40   Slim and stylish long-handle laptop purse for ...
#
#                                               Category
# 0     Home & Kitchen Kitchen & Dining Kitchen Utens...
# 541   Beauty & Personal Care › Shave & Hair Removal...
# 34    Sports & Outdoors › Outdoor Recreation › Camp...
# 551   Electronics Computers & Accessories Computer ...
# 285   Beauty & Personal Care › Oral Care › Oral Pai...
# 240   Office Products Office & School Supplies Offi...
# 381   Sports & Outdoors Sports & Fitness Hunting & ...
# 349   Beauty & Personal Care Oral Care Denture Care...
# 463   Cell Phones & Accessories Accessories Screen ...
# 40    Electronics › Computers & Accessories › Lapto...
